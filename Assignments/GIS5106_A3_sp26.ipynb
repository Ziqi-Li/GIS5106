# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziqi-Li/GIS5106/blob/main/Assignments/GIS5106_A3_sp26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3
# **Due date/time:** Apr 10 Fri 23:59pm
#
# **Instruction**: Make a copy of this notebook and read through the questions and instructions. Write down code/text to perform the analysis.
#
# **Submission**: After you finish working on this notebook, click File->Download->Download .ipynb
#
# Please submit a notebook named A6_your_name.ipynb on Canvas.

# %% [markdown]
# ## Detailed instructions:
#
# In this assignment, we will practice machine learning and model interpretation with SHAP values.
#
#
# **Note**: From this assignment and onward, if you are interested in performing your analysis using your own data (e.g., you may have a dataset from a research project), you are very encouraged to do so.
#
#
# We will be re-using our data from previous assignment. You can re-use the same dependent variable (y), and I would suggest you to use more indepdendent variables because Machine Learning models are scalable to include more Xs. The steps are:
#
# 1) Fit an AutoML with FLAML to get the best model.
#
# 2) Perform accuracy assessment on the best model (by calculating R2 and RMSE) against the test dataset.
#
# 3) Calculate SHAP values for the best model. Visualize the summary plot and describe what you find.
#
# 4) Plot Partitial Dependence plot for each feature and describe what you see.
#
# You can refer to https://github.com/Ziqi-Li/GIS5106/blob/main/notebooks/W06%20Auto%20ML%20and%20SHAP.ipynb
#
# as a template.

# %% [markdown]
# You may need to install these three packages if working on colab:

# %%
pip install "flaml[automl]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.7/337.7 kB 25.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.2.0
#     Uninstalling xgboost-3.2.0:
#       Successfully uninstalled xgboost-3.2.0
# ...

# %%
pip install shap

# %% [markdown]
# Import all the packages needed to run the analysis

# %%
import geopandas as gpd
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import shap
from flaml import AutoML

# %% [markdown]
# Code to read in data and merge them into one final `GeoDataFrame`.

# %%
health_url = "https://raw.github.com/Ziqi-Li/GIS5106/main/data/cdc_health_county.csv"
health = pd.read_csv(health_url)

# %%
socio_demo_url = "https://raw.github.com/Ziqi-Li/GIS5106/main/data/acs_2019.csv"
socio_demo = pd.read_csv(socio_demo_url)

# %%
counties_url = "https://raw.github.com/Ziqi-Li/gis5106/master/data/us_counties.geojson"
counties = gpd.read_file(counties_url)

# %%
income_health = pd.merge(socio_demo, health, left_on = "county_id", right_on = "LocationID")

# %%
gdf_income_health = pd.merge(counties, income_health, on = "county_id")

# %% [markdown]
# Your code will start here, and your analysis will be based on this GeoDataFrame `gdf_income_health`.
